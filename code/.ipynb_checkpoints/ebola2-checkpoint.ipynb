# %%
import numpy as np
import scipy
from sklearn import *
import matplotlib.pyplot as plt
import csv
from dateutil.parser import parse
import requests
from bs4 import BeautifulSoup
import pickle
from mpl_toolkits.basemap import Basemap,shiftgrid

# %%
# %matplotlib inline

# %%
def getdata(filename):
    
    #filename = 'Liberia'
    
    fin = csv.reader(file('../data/'+filename+'.csv', 'rb'))
    data = []
    for line in fin:
        if line[0] == 'Country':
            head = line
        else:
            data.append(line)
    
    
    #print head
    #print data
    #for item in head:
    #    print item, head.index(item)
    
    def fil(x):return x[3]!='' and x[6] == 'Patient database'
    
    data = filter(fil,data)
    
    def parsedate(x):
        date = x.split('to ')[1]
        start = '05 January 2014'
        return (parse(date) - parse(start)).days   
    
    
    def strtoint(s):
        if s == '':
            return 0
        else:
            return int(float(s))
    
    def getinfo(x):return [x[0],x[3],x[5],x[6],parsedate(x[7]),strtoint(x[12])]
    
    data = map(getinfo,data)
    
   
    
    cities = set([line[1] for line in data])
    
    def cityfilter(s):
        def f(x):
            return x[1]==s
        return f
    
    citydata = {}
    for city in cities:
        citydata[city] = filter(cityfilter(city),data)
    return cities,citydata

# %%
def dict_union(train, wagon):
    for key, val in wagon.iteritems():
        if not isinstance(val, dict):
            train[key] = val
        else:
            subdict = train.setdefault(key, {})
            dict_union(subdict, val)


countries = ['Sierra', 'Liberia', 'Guinea']
abbr = {'Sierra':'SL', 'Liberia':'LR', 'Guinea':'GN'};
cityinfo = []
for country in countries:
    cities, citydata = getdata(country);
    for city in cities:
        cityinfo.append([abbr[country], city])

        
        
cities, citydata1 = getdata('Sierra')
cities, citydata2 = getdata('Liberia')
cities, citydata3 = getdata('Guinea')

citydata = citydata1
dict_union(citydata,citydata2)
dict_union(citydata,citydata3)

# %%
print cityinfo
# Out:
# [['SL', 'KENEMA'], ['SL', 'BOMBALI'], ['SL', 'TONKOLILI'], ['SL', 'KONO'], ['SL', 'PUJEHUN'], ['SL', 'FREETOWN'], ['SL', 'BO'], ['SL', 'KOINADUGU'], ['SL', 'KAILAHUN'], ['SL', 'MOYAMBA'], ['SL', 'WESTERN RURAL'], ['SL', 'KAMBIA'], ['SL', 'BONTHE'], ['SL', 'PORT LOKO'], ['LR', 'GBARPOLU'], ['LR', 'GRAND GEDEH'], ['LR', 'GRAND BASSA'], ['LR', 'GRAND KRU'], ['LR', 'MARGIBI'], ['LR', 'NIMBA'], ['LR', 'BOMI'], ['LR', 'LOFA'], ['LR', 'RIVERCESS'], ['LR', 'RIVER GEE'], ['LR', 'MONTSERRADO'], ['LR', 'GRAND CAPE MOUNT'], ['LR', 'MARYLAND'], ['LR', 'BONG'], ['LR', 'SINOE'], ['GN', 'DALABA'], ['GN', "N'ZEREKORE"], ['GN', 'DABOLA'], ['GN', 'FARANAH'], ['GN', 'TELIMELE'], ['GN', 'LOLA'], ['GN', 'SIGUIRI'], ['GN', 'COYAH'], ['GN', 'KOUROUSSA'], ['GN', 'BEYLA'], ['GN', 'CONAKRY'], ['GN', 'KINDIA'], ['GN', 'MALI'], ['GN', 'PITA'], ['GN', 'KEROUANE'], ['GN', 'FORECARIAH'], ['GN', 'KISSIDOUGO'], ['GN', 'DINGUIRAYE'], ['GN', 'TOUGUE'], ['GN', 'GUECKEDOU'], ['GN', 'KANKAN'], ['GN', 'YOMOU'], ['GN', 'MACENTA'], ['GN', 'FRIA'], ['GN', 'BOKE'], ['GN', 'DUBREKA'], ['GN', 'BOFFA']]

# %%
len(cityinfo)
# Out:
# 56

# %%
def OnlyCharNum(s,oth=''):
    s2 = s.lower();
    fomart = 'abcdefghijklmnopqrstuvwxyz0123456789'
    for c in s2:
        if not c in fomart:
            s = s.replace(c,'');
    return s;

ccinfo = []
for info in cityinfo:
    url = 'http://www.geonames.org/search.html?q='+info[1]+'&country='+info[0]
    r = requests.get(url)
    soup = BeautifulSoup(r.text)
    lines = []
    if soup.body != None:
        if soup.body.div != None:
            if soup.body.div.table != None:
                lines = soup.body.div.table.find_all('tr')
    
    
    
    
    for line in lines:
        #print line.prettify()
        #print line.find_all('span').span
        #print line
        #print 1
        if line == None:
            continue
        if line.td!=None:
            if line.td.small!=None:
                smalls = line.find_all('small')
                #print line.td
                cinfo = []
                #print smalls
                if smalls[0].contents[0] == u'1':
                    #print info,smalls
                    cinfo.append(info[0])
                    cinfo.append(info[1])
                    if len(smalls) >= 3:
                        ss = smalls[len(smalls)-1].contents[0]
                        if ss.find('pop')!= -1:
                            pop = ss.split('ion ')[1]
                            #print pop
                            pop = OnlyCharNum(pop);
                            cinfo.append(int(pop))
                        else:
                            cinfo.append(0)
                    else:
                        cinfo.append('')
                    if line.span!=None:
                        for s in line.span:
                            cinfo.append(float(s.contents[0]))
                    else:
                        cinfo.append('')
                        cinfo.append('')
                elif (smalls[0].contents[0] == u'2'): 
                    #print smalls
                    if len(smalls)>1:
                        if smalls[1].contents!=[]:
                            #print smalls[1].contents
                            if ('Dis' in smalls[1].contents[0]):
                                #print info,smalls
                                cinfo.append(info[0])
                                cinfo.append(info[1])
                                if len(smalls) >= 3:
                                    ss = smalls[len(smalls)-1].contents[0]
                                    if ss.find('pop')!= -1:
                                        pop = ss.split('ion ')[1]
                                        #print pop
                                        pop = OnlyCharNum(pop);
                                        cinfo.append(int(pop))
                                    else:
                                        cinfo.append(0)
                                else:
                                    cinfo.append('')
                                if line.span!=None:
                                    for s in line.span:
                                        cinfo.append(float(s.contents[0]))
                                else:
                                    cinfo.append('')
                                    cinfo.append('')
                            
                
                    
                    
        if cinfo!=[]:
            print cinfo
            ccinfo.append(cinfo)
# Out:
# ['SL', 'KENEMA', 143137, 7.87687, -11.190245]
# ['SL', 'KENEMA', 493928, 7.951709, -11.190037]
# ['SL', 'BOMBALI', 409254, 9.284438, -12.164489]
# ['SL', 'TONKOLILI', 350353, 8.618846, -11.841731]
# ['SL', 'KONO', 337954, 8.706871, -10.933683]
# ['SL', 'PUJEHUN', 240682, 7.318547, -11.5792]
# ['SL', 'FREETOWN', 802639, 8.48400258773548, -13.229942321777344]
# ['SL', 'BO', 174354, 7.9647222, -11.7383333]
# ['SL', 'BO', 482884, 7.988772, -11.673402]
# ['SL', 'KOINADUGU', 236269, 9.509906, -11.346011]
# ['SL', 'KAILAHUN', 14085, 8.278903, -10.572998]
# ['SL', 'KAILAHUN', 363767, 8.107683, -10.751456]
# ['SL', 'MOYAMBA', 258909, 8.062898, -12.444007]
# ['SL', 'WESTERN RURAL', 0, 8.323185, -13.094851]
# ['SL', 'KAMBIA', 281141, 9.182514, -12.813094]
# ['SL', 'BONTHE', 131580, 7.516217, -12.335906]
# ['SL', 'PORT LOKO', 21308, 8.7666667, -12.7833333]
# ['SL', 'PORT LOKO', 460230, 8.723858, -12.759044]
# ['LR', 'GBARPOLU', '', 7.1666667, -10.4166667]
# ['LR', 'GRAND GEDEH', 25678, 6.068462, -8.135585]
# ['LR', 'GRAND BASSA', 25731, 5.881086, -10.044724]
# ['LR', 'GRAND KRU', '', 4.9166667, -8.25]
# ['LR', 'MARGIBI', 33945, 6.531469, -10.353574]
# ['LR', 'NIMBA', '', 6.75, -8.75]
# ['LR', 'BOMI', '', 6.666667, -10.833333]
# ['LR', 'LOFA', 26594, 8.4219444, -9.7477778]
# ['LR', 'RIVERCESS', 72000, 6.0, -9.3333333]
# ['LR', 'RIVER GEE', '', 5.25, -7.9166667]
# ['LR', 'MONTSERRADO', 939524, 6.300539726631287, -10.796899795532227]
# ['LR', 'GRAND CAPE MOUNT', '', 7.1666667, -11.0]
# ['LR', 'MARYLAND', 32661, 4.378199, -7.710813]
# ['LR', 'BONG', 45835, 6.9955556, -9.4722222]
# ['LR', 'SINOE', 16434, 5.0111111, -9.0388889]
# ['GN', 'DALABA', 154820, 10.75, -12.3]
# ['GN', "N'ZEREKORE", '', '', '']
# ['GN', 'DABOLA', 114250, 10.6, -11.116667]
# ['GN', 'FARANAH', '', 10.3375, -10.69583335]
# ['GN', 'TELIMELE', 283642, 10.9166667, -13.3333333]
# ['GN', 'LOLA', 124393, 7.833333, -8.333333]
# ['GN', 'SIGUIRI', 243888, 11.6666667, -9.5]
# ['GN', 'COYAH', 77103, 9.705556, -13.376944]
# ['GN', 'KOUROUSSA', 159600, 10.666667, -9.916667]
# ['GN', 'BEYLA', 188045, 8.9166667, -8.4166667]
# ['GN', 'CONAKRY', 1767200, 9.537949753673535, -13.677291870117188]
# ['GN', 'KINDIA', 117062, 10.056923953951774, -12.865762710571289]
# ['GN', 'MALI', 245870, 12.0833333, -12.0833333]
# ['GN', 'PITA', 265689, 10.833333, -12.583333]
# ['GN', 'KEROUANE', 124625, 9.1666667, -9.0833333]
# ['GN', 'FORECARIAH', 135817, 9.4333333, -13.1]
# ['GN', 'DINGUIRAYE', 155636, 11.545, -10.675]
# ['GN', 'TOUGUE', 132086, 11.4666667, -11.6]
# ['GN', 'GUECKEDOU', 79140, 8.567441790924521, -10.133600234985352]
# ['GN', 'KANKAN', 114009, 10.38542172084099, -9.30567741394043]
# ['GN', 'YOMOU', 86736, 7.5, -9.166667]
# ['GN', 'MACENTA', 296192, 8.5, -9.416667]
# ['GN', 'FRIA', 82073, 10.416667, -13.583333]
# ['GN', 'BOKE', 61527, 10.6666667, -14.6]
# ['GN', 'DUBREKA', 0, 10.25, -13.4166667]
# ['GN', 'BOFFA', 165196, 10.333333, -14.166667]

# %%
len(cityinfo)

# %%
len(ccinfo)
def fil(x):return x[2]!=''
c = filter(fil,ccinfo)

# %%
posx = [info[3] for info in c]
posy = [info[4] for info in c]
m = Basemap(width=1200000,height=1000000,projection='lcc',
            resolution='h',lat_1=15.,lat_2=-7,lat_0=9,lon_0=-10.)
d1 = 80
d2 = 200
w = 10
d = 4
fig = plt.figure(figsize=(20,40))
for i in range(28):
    d1 = 14*i
    d2 = 14*i + 14
    size = []
    for info in c:
        s = 0
        for record in citydata[info[1]]:
            if (record[4] > d1) and (record[4] < d2) and (record[2] == 'Confirmed'):
                s = s + record[5]
        size.append(s)
    
    plt.subplot(w,d,i+1)
    m.drawcoastlines()
    m.drawcountries()
    for i in range(len(posx)):
        xpt,ypt = m(posy[i], posx[i])
        m.plot(xpt,ypt,'ro',markersize=max(np.sqrt(size[i])*2,3.5)*(size[i]>0),alpha=0.5) 
        #plt.text(xpt+10000,ypt+10000,'%s' % (c[i][1]),fontsize = 4)
    #plt.scatter(posy,posx,size,'r')
        plt.xlabel('From day '+ str(d1)+' to day '+str(d2) )
plt.savefig('newonmap.png', dpi=300)
plt.savefig('newonmap.pdf')

# %%
output = open('newcity.pkl', 'wb')
pickle.dump(filteredinfo, output)
output.close()

# %%
ccinfo
# Out:
# [['SL', 'KENEMA', 143137, 7.87687, -11.190245],
#  ['SL', 'KENEMA', 493928, 7.951709, -11.190037],
#  ['SL', 'BOMBALI', 409254, 9.284438, -12.164489],
#  ['SL', 'TONKOLILI', 350353, 8.618846, -11.841731],
#  ['SL', 'KONO', 337954, 8.706871, -10.933683],
#  ['SL', 'PUJEHUN', 240682, 7.318547, -11.5792],
#  ['SL', 'FREETOWN', 802639, 8.48400258773548, -13.229942321777344],
#  ['SL', 'BO', 174354, 7.9647222, -11.7383333],
#  ['SL', 'BO', 482884, 7.988772, -11.673402],
#  ['SL', 'KOINADUGU', 236269, 9.509906, -11.346011],
#  ['SL', 'KAILAHUN', 14085, 8.278903, -10.572998],
#  ['SL', 'KAILAHUN', 363767, 8.107683, -10.751456],
#  ['SL', 'MOYAMBA', 258909, 8.062898, -12.444007],
#  ['SL', 'WESTERN RURAL', 0, 8.323185, -13.094851],
#  ['SL', 'KAMBIA', 281141, 9.182514, -12.813094],
#  ['SL', 'BONTHE', 131580, 7.516217, -12.335906],
#  ['SL', 'PORT LOKO', 21308, 8.7666667, -12.7833333],
#  ['SL', 'PORT LOKO', 460230, 8.723858, -12.759044],
#  ['LR', 'GBARPOLU', '', 7.1666667, -10.4166667],
#  ['LR', 'GRAND GEDEH', 25678, 6.068462, -8.135585],
#  ['LR', 'GRAND BASSA', 25731, 5.881086, -10.044724],
#  ['LR', 'GRAND KRU', '', 4.9166667, -8.25],
#  ['LR', 'MARGIBI', 33945, 6.531469, -10.353574],
#  ['LR', 'NIMBA', '', 6.75, -8.75],
#  ['LR', 'BOMI', '', 6.666667, -10.833333],
#  ['LR', 'LOFA', 26594, 8.4219444, -9.7477778],
#  ['LR', 'RIVERCESS', 72000, 6.0, -9.3333333],
#  ['LR', 'RIVER GEE', '', 5.25, -7.9166667],
#  ['LR', 'MONTSERRADO', 939524, 6.300539726631287, -10.796899795532227],
#  ['LR', 'GRAND CAPE MOUNT', '', 7.1666667, -11.0],
#  ['LR', 'MARYLAND', 32661, 4.378199, -7.710813],
#  ['LR', 'BONG', 45835, 6.9955556, -9.4722222],
#  ['LR', 'SINOE', 16434, 5.0111111, -9.0388889],
#  ['GN', 'DALABA', 154820, 10.75, -12.3],
#  ['GN', "N'ZEREKORE", '', '', ''],
#  ['GN', 'DABOLA', 114250, 10.6, -11.116667],
#  ['GN', 'FARANAH', '', 10.3375, -10.69583335],
#  ['GN', 'TELIMELE', 283642, 10.9166667, -13.3333333],
#  ['GN', 'LOLA', 124393, 7.833333, -8.333333],
#  ['GN', 'SIGUIRI', 243888, 11.6666667, -9.5],
#  ['GN', 'COYAH', 77103, 9.705556, -13.376944],
#  ['GN', 'KOUROUSSA', 159600, 10.666667, -9.916667],
#  ['GN', 'BEYLA', 188045, 8.9166667, -8.4166667],
#  ['GN', 'CONAKRY', 1767200, 9.537949753673535, -13.677291870117188],
#  ['GN', 'KINDIA', 117062, 10.056923953951774, -12.865762710571289],
#  ['GN', 'MALI', 245870, 12.0833333, -12.0833333],
#  ['GN', 'PITA', 265689, 10.833333, -12.583333],
#  ['GN', 'KEROUANE', 124625, 9.1666667, -9.0833333],
#  ['GN', 'FORECARIAH', 135817, 9.4333333, -13.1],
#  ['GN', 'DINGUIRAYE', 155636, 11.545, -10.675],
#  ['GN', 'TOUGUE', 132086, 11.4666667, -11.6],
#  ['GN', 'GUECKEDOU', 79140, 8.567441790924521, -10.133600234985352],
#  ['GN', 'KANKAN', 114009, 10.38542172084099, -9.30567741394043],
#  ['GN', 'YOMOU', 86736, 7.5, -9.166667],
#  ['GN', 'MACENTA', 296192, 8.5, -9.416667],
#  ['GN', 'FRIA', 82073, 10.416667, -13.583333],
#  ['GN', 'BOKE', 61527, 10.6666667, -14.6],
#  ['GN', 'DUBREKA', 0, 10.25, -13.4166667],
#  ['GN', 'BOFFA', 165196, 10.333333, -14.166667],
#  ['GN', 'DUBREKA', 8300, 10.25, -13.4166667],
#  (['SL', 'WESTERN RURAL', 197098, 8.323185, -13.094851],),
#  ['LR', 'GBARPOLU', 83758, 7.1666667, -10.4166667],
#  ['LR', 'GRAND KRU', 57106, 4.9166667, -8.25],
#  ['LR', 'NIMBA', 462026, 6.75, -8.75],
#  ['LR', 'BOMI', 84119, 6.666667, -10.833333],
#  ['LR', 'RIVER GEE', 66789, 5.25, -7.9166667]]

# %%
cinfo = ['GN', 'FARANAH', 78108, 10.3375, -10.69583335]
ccinfo.append(cinfo)

# %%
backup = ccinfo

# %%
for info in ccinfo:
    print info, ccinfo.index(info)
    
def f(x):return (x[2]!='') and (x[3]!='') and (x[4]!='')

filteredinfo = filter(f,ccinfo)
# Out:
# ['SL', 'KENEMA', 143137, 7.87687, -11.190245] 0
# ['SL', 'KENEMA', 493928, 7.951709, -11.190037] 1
# ['SL', 'BOMBALI', 409254, 9.284438, -12.164489] 2
# ['SL', 'TONKOLILI', 350353, 8.618846, -11.841731] 3
# ['SL', 'KONO', 337954, 8.706871, -10.933683] 4
# ['SL', 'PUJEHUN', 240682, 7.318547, -11.5792] 5
# ['SL', 'FREETOWN', 802639, 8.48400258773548, -13.229942321777344] 6
# ['SL', 'BO', 174354, 7.9647222, -11.7383333] 7
# ['SL', 'BO', 482884, 7.988772, -11.673402] 8
# ['SL', 'KOINADUGU', 236269, 9.509906, -11.346011] 9
# ['SL', 'KAILAHUN', 14085, 8.278903, -10.572998] 10
# ['SL', 'KAILAHUN', 363767, 8.107683, -10.751456] 11
# ['SL', 'MOYAMBA', 258909, 8.062898, -12.444007] 12
# ['SL', 'WESTERN RURAL', 0, 8.323185, -13.094851] 13
# ['SL', 'KAMBIA', 281141, 9.182514, -12.813094] 14
# ['SL', 'BONTHE', 131580, 7.516217, -12.335906] 15
# ['SL', 'PORT LOKO', 21308, 8.7666667, -12.7833333] 16
# ['SL', 'PORT LOKO', 460230, 8.723858, -12.759044] 17
# ['LR', 'GBARPOLU', '', 7.1666667, -10.4166667] 18
# ['LR', 'GRAND GEDEH', 25678, 6.068462, -8.135585] 19
# ['LR', 'GRAND BASSA', 25731, 5.881086, -10.044724] 20
# ['LR', 'GRAND KRU', '', 4.9166667, -8.25] 21
# ['LR', 'MARGIBI', 33945, 6.531469, -10.353574] 22
# ['LR', 'NIMBA', '', 6.75, -8.75] 23
# ['LR', 'BOMI', '', 6.666667, -10.833333] 24
# ['LR', 'LOFA', 26594, 8.4219444, -9.7477778] 25
# ['LR', 'RIVERCESS', 72000, 6.0, -9.3333333] 26
# ['LR', 'RIVER GEE', '', 5.25, -7.9166667] 27
# ['LR', 'MONTSERRADO', 939524, 6.300539726631287, -10.796899795532227] 28
# ['LR', 'GRAND CAPE MOUNT', '', 7.1666667, -11.0] 29
# ['LR', 'MARYLAND', 32661, 4.378199, -7.710813] 30
# ['LR', 'BONG', 45835, 6.9955556, -9.4722222] 31
# ['LR', 'SINOE', 16434, 5.0111111, -9.0388889] 32
# ['GN', 'DALABA', 154820, 10.75, -12.3] 33
# ['GN', "N'ZEREKORE", '', '', ''] 34
# ['GN', 'DABOLA', 114250, 10.6, -11.116667] 35
# ['GN', 'FARANAH', '', 10.3375, -10.69583335] 36
# ['GN', 'TELIMELE', 283642, 10.9166667, -13.3333333] 37
# ['GN', 'LOLA', 124393, 7.833333, -8.333333] 38
# ['GN', 'SIGUIRI', 243888, 11.6666667, -9.5] 39
# ['GN', 'COYAH', 77103, 9.705556, -13.376944] 40
# ['GN', 'KOUROUSSA', 159600, 10.666667, -9.916667] 41
# ['GN', 'BEYLA', 188045, 8.9166667, -8.4166667] 42
# ['GN', 'CONAKRY', 1767200, 9.537949753673535, -13.677291870117188] 43
# ['GN', 'KINDIA', 117062, 10.056923953951774, -12.865762710571289] 44
# ['GN', 'MALI', 245870, 12.0833333, -12.0833333] 45
# ['GN', 'PITA', 265689, 10.833333, -12.583333] 46
# ['GN', 'KEROUANE', 124625, 9.1666667, -9.0833333] 47
# ['GN', 'FORECARIAH', 135817, 9.4333333, -13.1] 48
# ['GN', 'DINGUIRAYE', 155636, 11.545, -10.675] 49
# ['GN', 'TOUGUE', 132086, 11.4666667, -11.6] 50
# ['GN', 'GUECKEDOU', 79140, 8.567441790924521, -10.133600234985352] 51
# ['GN', 'KANKAN', 114009, 10.38542172084099, -9.30567741394043] 52
# ['GN', 'YOMOU', 86736, 7.5, -9.166667] 53
# ['GN', 'MACENTA', 296192, 8.5, -9.416667] 54
# ['GN', 'FRIA', 82073, 10.416667, -13.583333] 55
# ['GN', 'BOKE', 61527, 10.6666667, -14.6] 56
# ['GN', 'DUBREKA', 0, 10.25, -13.4166667] 57
# ['GN', 'BOFFA', 165196, 10.333333, -14.166667] 58
# ['GN', 'DUBREKA', 8300, 10.25, -13.4166667] 59
# ['LR', 'GBARPOLU', 83758, 7.1666667, -10.4166667] 60
# ['LR', 'GRAND KRU', 57106, 4.9166667, -8.25] 61
# ['LR', 'NIMBA', 462026, 6.75, -8.75] 62
# ['LR', 'BOMI', 84119, 6.666667, -10.833333] 63
# ['LR', 'RIVER GEE', 66789, 5.25, -7.9166667] 64
# ['SL', 'WESTERN RURAL', 197098, 8.323185, -13.094851] 65
# ['LR', 'GRAND CAPE MOUNT', 129055, 7.1666667, -11.0] 66
# ['GN', "N'ZEREKORE", 300000, 7.75, -8.816667] 67
# ['GN', 'FARANAH', 78108, 10.3375, -10.69583335] 68

# %%
for i in range(len(filteredinfo)):
    for j in range(i):
        if (filteredinfo[i][2] > filteredinfo[j][2]) and (filteredinfo[i][1] == filteredinfo[j][1]):
            filteredinfo[j][2] = ''

# %%
filteredinfo
# Out:
# [['SL', 'KENEMA', 493928, 7.951709, -11.190037],
#  ['SL', 'BOMBALI', 409254, 9.284438, -12.164489],
#  ['SL', 'TONKOLILI', 350353, 8.618846, -11.841731],
#  ['SL', 'KONO', 337954, 8.706871, -10.933683],
#  ['SL', 'PUJEHUN', 240682, 7.318547, -11.5792],
#  ['SL', 'FREETOWN', 802639, 8.48400258773548, -13.229942321777344],
#  ['SL', 'BO', 482884, 7.988772, -11.673402],
#  ['SL', 'KOINADUGU', 236269, 9.509906, -11.346011],
#  ['SL', 'KAILAHUN', 363767, 8.107683, -10.751456],
#  ['SL', 'MOYAMBA', 258909, 8.062898, -12.444007],
#  ['SL', 'KAMBIA', 281141, 9.182514, -12.813094],
#  ['SL', 'BONTHE', 131580, 7.516217, -12.335906],
#  ['SL', 'PORT LOKO', 460230, 8.723858, -12.759044],
#  ['LR', 'GRAND GEDEH', 25678, 6.068462, -8.135585],
#  ['LR', 'GRAND BASSA', 25731, 5.881086, -10.044724],
#  ['LR', 'MARGIBI', 33945, 6.531469, -10.353574],
#  ['LR', 'LOFA', 26594, 8.4219444, -9.7477778],
#  ['LR', 'RIVERCESS', 72000, 6.0, -9.3333333],
#  ['LR', 'MONTSERRADO', 939524, 6.300539726631287, -10.796899795532227],
#  ['LR', 'MARYLAND', 32661, 4.378199, -7.710813],
#  ['LR', 'BONG', 45835, 6.9955556, -9.4722222],
#  ['LR', 'SINOE', 16434, 5.0111111, -9.0388889],
#  ['GN', 'DALABA', 154820, 10.75, -12.3],
#  ['GN', 'DABOLA', 114250, 10.6, -11.116667],
#  ['GN', 'TELIMELE', 283642, 10.9166667, -13.3333333],
#  ['GN', 'LOLA', 124393, 7.833333, -8.333333],
#  ['GN', 'SIGUIRI', 243888, 11.6666667, -9.5],
#  ['GN', 'COYAH', 77103, 9.705556, -13.376944],
#  ['GN', 'KOUROUSSA', 159600, 10.666667, -9.916667],
#  ['GN', 'BEYLA', 188045, 8.9166667, -8.4166667],
#  ['GN', 'CONAKRY', 1767200, 9.537949753673535, -13.677291870117188],
#  ['GN', 'KINDIA', 117062, 10.056923953951774, -12.865762710571289],
#  ['GN', 'MALI', 245870, 12.0833333, -12.0833333],
#  ['GN', 'PITA', 265689, 10.833333, -12.583333],
#  ['GN', 'KEROUANE', 124625, 9.1666667, -9.0833333],
#  ['GN', 'FORECARIAH', 135817, 9.4333333, -13.1],
#  ['GN', 'DINGUIRAYE', 155636, 11.545, -10.675],
#  ['GN', 'TOUGUE', 132086, 11.4666667, -11.6],
#  ['GN', 'GUECKEDOU', 79140, 8.567441790924521, -10.133600234985352],
#  ['GN', 'KANKAN', 114009, 10.38542172084099, -9.30567741394043],
#  ['GN', 'YOMOU', 86736, 7.5, -9.166667],
#  ['GN', 'MACENTA', 296192, 8.5, -9.416667],
#  ['GN', 'FRIA', 82073, 10.416667, -13.583333],
#  ['GN', 'BOKE', 61527, 10.6666667, -14.6],
#  ['GN', 'BOFFA', 165196, 10.333333, -14.166667],
#  ['GN', 'DUBREKA', 8300, 10.25, -13.4166667],
#  ['LR', 'GBARPOLU', 83758, 7.1666667, -10.4166667],
#  ['LR', 'GRAND KRU', 57106, 4.9166667, -8.25],
#  ['LR', 'NIMBA', 462026, 6.75, -8.75],
#  ['LR', 'BOMI', 84119, 6.666667, -10.833333],
#  ['LR', 'RIVER GEE', 66789, 5.25, -7.9166667],
#  ['SL', 'WESTERN RURAL', 197098, 8.323185, -13.094851],
#  ['LR', 'GRAND CAPE MOUNT', 129055, 7.1666667, -11.0],
#  ['GN', "N'ZEREKORE", 300000, 7.75, -8.816667],
#  ['GN', 'FARANAH', 78108, 10.3375, -10.69583335]]

# %%
c = filteredinfo

# %%
c
# Out:
# [['SL', 'KENEMA', 493928, 7.951709, -11.190037],
#  ['SL', 'BOMBALI', 409254, 9.284438, -12.164489],
#  ['SL', 'TONKOLILI', 350353, 8.618846, -11.841731],
#  ['SL', 'KONO', 337954, 8.706871, -10.933683],
#  ['SL', 'PUJEHUN', 240682, 7.318547, -11.5792],
#  ['SL', 'FREETOWN', 802639, 8.48400258773548, -13.229942321777344],
#  ['SL', 'BO', 482884, 7.988772, -11.673402],
#  ['SL', 'KOINADUGU', 236269, 9.509906, -11.346011],
#  ['SL', 'KAILAHUN', 363767, 8.107683, -10.751456],
#  ['SL', 'MOYAMBA', 258909, 8.062898, -12.444007],
#  ['SL', 'KAMBIA', 281141, 9.182514, -12.813094],
#  ['SL', 'BONTHE', 131580, 7.516217, -12.335906],
#  ['SL', 'PORT LOKO', 460230, 8.723858, -12.759044],
#  ['LR', 'GRAND GEDEH', 25678, 6.068462, -8.135585],
#  ['LR', 'GRAND BASSA', 25731, 5.881086, -10.044724],
#  ['LR', 'MARGIBI', 33945, 6.531469, -10.353574],
#  ['LR', 'LOFA', 26594, 8.4219444, -9.7477778],
#  ['LR', 'RIVERCESS', 72000, 6.0, -9.3333333],
#  ['LR', 'MONTSERRADO', 939524, 6.300539726631287, -10.796899795532227],
#  ['LR', 'MARYLAND', 32661, 4.378199, -7.710813],
#  ['LR', 'BONG', 45835, 6.9955556, -9.4722222],
#  ['LR', 'SINOE', 16434, 5.0111111, -9.0388889],
#  ['GN', 'DALABA', 154820, 10.75, -12.3],
#  ['GN', 'DABOLA', 114250, 10.6, -11.116667],
#  ['GN', 'TELIMELE', 283642, 10.9166667, -13.3333333],
#  ['GN', 'LOLA', 124393, 7.833333, -8.333333],
#  ['GN', 'SIGUIRI', 243888, 11.6666667, -9.5],
#  ['GN', 'COYAH', 77103, 9.705556, -13.376944],
#  ['GN', 'KOUROUSSA', 159600, 10.666667, -9.916667],
#  ['GN', 'BEYLA', 188045, 8.9166667, -8.4166667],
#  ['GN', 'CONAKRY', 1767200, 9.537949753673535, -13.677291870117188],
#  ['GN', 'KINDIA', 117062, 10.056923953951774, -12.865762710571289],
#  ['GN', 'MALI', 245870, 12.0833333, -12.0833333],
#  ['GN', 'PITA', 265689, 10.833333, -12.583333],
#  ['GN', 'KEROUANE', 124625, 9.1666667, -9.0833333],
#  ['GN', 'FORECARIAH', 135817, 9.4333333, -13.1],
#  ['GN', 'DINGUIRAYE', 155636, 11.545, -10.675],
#  ['GN', 'TOUGUE', 132086, 11.4666667, -11.6],
#  ['GN', 'GUECKEDOU', 79140, 8.567441790924521, -10.133600234985352],
#  ['GN', 'KANKAN', 114009, 10.38542172084099, -9.30567741394043],
#  ['GN', 'YOMOU', 86736, 7.5, -9.166667],
#  ['GN', 'MACENTA', 296192, 8.5, -9.416667],
#  ['GN', 'FRIA', 82073, 10.416667, -13.583333],
#  ['GN', 'BOKE', 61527, 10.6666667, -14.6],
#  ['GN', 'BOFFA', 165196, 10.333333, -14.166667],
#  ['GN', 'DUBREKA', 8300, 10.25, -13.4166667],
#  ['LR', 'GBARPOLU', 83758, 7.1666667, -10.4166667],
#  ['LR', 'GRAND KRU', 57106, 4.9166667, -8.25],
#  ['LR', 'NIMBA', 462026, 6.75, -8.75],
#  ['LR', 'BOMI', 84119, 6.666667, -10.833333],
#  ['LR', 'RIVER GEE', 66789, 5.25, -7.9166667],
#  ['SL', 'WESTERN RURAL', 197098, 8.323185, -13.094851],
#  ['LR', 'GRAND CAPE MOUNT', 129055, 7.1666667, -11.0],
#  ['GN', "N'ZEREKORE", 300000, 7.75, -8.816667],
#  ['GN', 'FARANAH', 78108, 10.3375, -10.69583335]]
